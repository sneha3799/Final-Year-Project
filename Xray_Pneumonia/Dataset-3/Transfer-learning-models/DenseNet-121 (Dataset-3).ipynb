# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-f75f605c-30c9-412c-a398-a4ade1953e2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f75f605c-30c9-412c-a398-a4ade1953e2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets download -d mrinath/pneumonia
# Out:
# Downloading pneumonia.zip to /content
#  99% 1.16G/1.17G [00:09<00:00, 143MB/s]
# 100% 1.17G/1.17G [00:09<00:00, 128MB/s]

# %%
import zipfile
zf = "/content/pneumonia.zip"
target_dir = "/content/dataset/cnn/pneumonia"
zfile = zipfile.ZipFile(zf)
zfile.extractall(target_dir)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
train_path = '/content/dataset/cnn/pneumonia/folders/train'
test_path = '/content/dataset/cnn/pneumonia/folders/test'
valid_path = '/content/dataset/cnn/pneumonia/folders/valid'

# %%
batch_size = 19

img_height = 150
img_width = 150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
image_gen = ImageDataGenerator(rescale=1./255,zoom_range=0.4,shear_range=0.3,vertical_flip=True)
test_data_gen = ImageDataGenerator(rescale=1./255)

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD

from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

import gdown
import zipfile

import os
import tensorflow as tf
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import model_selection

from collections import Counter

import keras
from keras.models import Sequential
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, GlobalAveragePooling2D

import keras.optimizers as optimizers
from keras.callbacks import ModelCheckpoint

from keras.applications import DenseNet121

from imgaug import augmenters

# %%
train = image_gen.flow_from_directory(train_path,target_size=(img_height,img_width),class_mode='binary',batch_size=batch_size)
test = test_data_gen.flow_from_directory(test_path,target_size=(img_height,img_width),shuffle=False,class_mode='binary',batch_size=batch_size)
valid = test_data_gen.flow_from_directory(valid_path,target_size=(img_height,img_width),class_mode='binary',batch_size=batch_size)
# Out:
# Found 4883 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 349 images belonging to 2 classes.

# %%
plt.figure(figsize=(12,12))
for i in range(0,10):
  plt.subplot(2,5,i+1)
  for X_batch,Y_batch in train:
    image = X_batch[0]
    dic = {0:'Normal',1:'Pneumonia'}
    plt.title(dic.get(Y_batch[0]))
    plt.axis('off')

    plt.imshow(np.squeeze(image),cmap='gray',interpolation='nearest')
    break

    plt.tight_layout()
    plt.show()

# %%
expert_conv = DenseNet121(weights = 'imagenet', include_top = False,input_shape=(img_width, img_height, 3),input_tensor=None,pooling=None)

for layer in expert_conv.layers:
      trainable = True
      layer.trainable = trainable


expert_model = Sequential()
# expert_model.add(Reshape((64,64,3)))
expert_model.add(expert_conv)
expert_model.add(GlobalAveragePooling2D())

expert_model.add(Dense(128, activation = 'relu'))
expert_model.add(Dropout(0.3))
expert_model.add(Dense(64, activation = 'relu'))
expert_model.add(Dense(1, activation = "sigmoid"))

opt = keras.optimizers.SGD(lr=1e-4, momentum=0.95)

expert_model.compile(loss = "binary_crossentropy", optimizer = opt, metrics=['accuracy'])

# %%
expert_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 14,788,673
# Trainable params: 14,788,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(expert_model,show_shapes=True,show_layer_names=True,rankdir='TB',expand_nested=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
early = EarlyStopping(monitor="val_loss",mode="min",patience=3)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',patience=2,verbose=1,factor=0.3,min_lr=0.000001)
callbacks_list = [early,learning_rate_reduction]

# %%
from sklearn.utils.class_weight import compute_class_weight
weights = compute_class_weight('balanced',np.unique(train.classes),train.classes)
cw = dict(zip(np.unique(train.classes),weights))
print(cw)
# Out:
# {0: 2.0761054421768708, 1: 0.6586188292419747}

# %%
checkpoint_path = "training_2/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

expert_model.fit(train,epochs=25,validation_data=valid,class_weight=cw,batch_size=512)
# Out:
# Epoch 1/25
# 257/257 [==============================] - 94s 326ms/step - loss: 0.6255 - accuracy: 0.5756 - val_loss: 0.2601 - val_accuracy: 0.9169
# Epoch 2/25
# 257/257 [==============================] - 82s 319ms/step - loss: 0.2534 - accuracy: 0.9103 - val_loss: 0.2113 - val_accuracy: 0.9255
# Epoch 3/25
# 257/257 [==============================] - 82s 319ms/step - loss: 0.1950 - accuracy: 0.9285 - val_loss: 0.2194 - val_accuracy: 0.9169
# Epoch 4/25
# 257/257 [==============================] - 83s 321ms/step - loss: 0.1684 - accuracy: 0.9393 - val_loss: 0.2866 - val_accuracy: 0.9054
# Epoch 5/25
# 257/257 [==============================] - 83s 324ms/step - loss: 0.1569 - accuracy: 0.9457 - val_loss: 0.1461 - val_accuracy: 0.9427
# Epoch 6/25
# 257/257 [==============================] - 83s 321ms/step - loss: 0.1516 - accuracy: 0.9439 - val_loss: 0.5025 - val_accuracy: 0.8510
# Epoch 7/25
# 257/257 [==============================] - 83s 322ms/step - loss: 0.1391 - accuracy: 0.9509 - val_loss: 0.0908 - val_accuracy: 0.9742
# Epoch 8/25
# 257/257 [==============================] - 82s 320ms/step - loss: 0.1266 - accuracy: 0.9540 - val_loss: 0.9340 - val_accuracy: 0.7135
# Epoch 9/25
# 257/257 [==============================] - 82s 321ms/step - loss: 0.1089 - accuracy: 0.9570 - val_loss: 0.1131 - val_accuracy: 0.9542
# Epoch 10/25
# 257/257 [==============================] - 82s 320ms/step - loss: 0.1033 - accuracy: 0.9551 - val_loss: 0.3924 - val_accuracy: 0.8825
# Epoch 11/25
# 257/257 [==============================] - 82s 317ms/step - loss: 0.1037 - accuracy: 0.9564 - val_loss: 0.5230 - val_accuracy: 0.8309
# Epoch 12/25
# 257/257 [==============================] - 82s 317ms/step - loss: 0.1104 - accuracy: 0.9594 - val_loss: 0.1007 - val_accuracy: 0.9599
# Epoch 13/25
# 257/257 [==============================] - 82s 319ms/step - loss: 0.1069 - accuracy: 0.9576 - val_loss: 0.0742 - val_accuracy: 0.9742
# Epoch 14/25
# 257/257 [==============================] - 82s 320ms/step - loss: 0.0796 - accuracy: 0.9694 - val_loss: 0.0775 - val_accuracy: 0.9685
# Epoch 15/25
# 257/257 [==============================] - 82s 320ms/step - loss: 0.0789 - accuracy: 0.9692 - val_loss: 0.0799 - val_accuracy: 0.9656
# Epoch 16/25
# 257/257 [==============================] - 82s 319ms/step - loss: 0.0797 - accuracy: 0.9705 - val_loss: 0.1121 - val_accuracy: 0.9713
# Epoch 17/25
# 257/257 [==============================] - 82s 320ms/step - loss: 0.0869 - accuracy: 0.9656 - val_loss: 0.0976 - val_accuracy: 0.9599
# Epoch 18/25
# 257/257 [==============================] - 82s 319ms/step - loss: 0.0825 - accuracy: 0.9726 - val_loss: 0.1055 - val_accuracy: 0.9542
# Epoch 19/25
# 257/257 [==============================] - 82s 320ms/step - loss: 0.0750 - accuracy: 0.9742 - val_loss: 0.6488 - val_accuracy: 0.7880
# Epoch 20/25
# 257/257 [==============================] - 81s 316ms/step - loss: 0.0796 - accuracy: 0.9757 - val_loss: 0.3171 - val_accuracy: 0.8797
# Epoch 21/25
# 257/257 [==============================] - 81s 316ms/step - loss: 0.0632 - accuracy: 0.9746 - val_loss: 0.0953 - val_accuracy: 0.9656
# Epoch 22/25
# 257/257 [==============================] - 81s 316ms/step - loss: 0.0670 - accuracy: 0.9736 - val_loss: 0.0477 - val_accuracy: 0.9857
# Epoch 23/25
# 257/257 [==============================] - 81s 316ms/step - loss: 0.0523 - accuracy: 0.9798 - val_loss: 0.1218 - val_accuracy: 0.9570
# Epoch 24/25
# 257/257 [==============================] - 81s 315ms/step - loss: 0.0555 - accuracy: 0.9766 - val_loss: 0.3713 - val_accuracy: 0.8854
# Epoch 25/25
# 257/257 [==============================] - 81s 315ms/step - loss: 0.0610 - accuracy: 0.9778 - val_loss: 0.1394 - val_accuracy: 0.9484

# %%
pd.DataFrame(expert_model.history.history).plot()

# %%
test_accu = expert_model.evaluate(test)
print('The testing accuracy is - ',test_accu[1]*100,'%')

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,f1_score, log_loss

y_bar = np.round(expert_model.predict(test)).reshape(-1)
y_act = test.labels

##accuracy
print("Accuracy: ",accuracy_score(y_bar,y_act))
##Roc_Auc Score
print("ROC-AUC score: ",roc_auc_score(y_bar,y_act))
##F1-Score Score
print("F1 score: ",f1_score(y_bar,y_act))
##Log Loss Score
print("Log Loss: ",log_loss(y_bar,y_act))
