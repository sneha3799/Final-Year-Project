# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-09e43e01-319c-4638-9b9e-2e39eb52141e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09e43e01-319c-4638-9b9e-2e39eb52141e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets download -d mrinath/pneumonia
# Out:
# Downloading pneumonia.zip to /content
#  98% 1.15G/1.17G [00:15<00:00, 184MB/s]
# 100% 1.17G/1.17G [00:15<00:00, 79.5MB/s]

# %%
import zipfile
zf = "/content/pneumonia.zip"
target_dir = "/content/dataset/cnn/pneumonia"
zfile = zipfile.ZipFile(zf)
zfile.extractall(target_dir)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
train_path = '/content/dataset/cnn/pneumonia/folders/train'
test_path = '/content/dataset/cnn/pneumonia/folders/test'
valid_path = '/content/dataset/cnn/pneumonia/folders/valid'

# %%
batch_size = 19

img_height = 150
img_width = 150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
image_gen = ImageDataGenerator(rescale=1./255,zoom_range=0.4,shear_range=0.3,vertical_flip=True)
test_data_gen = ImageDataGenerator(rescale=1./255)

# %%
train = image_gen.flow_from_directory(train_path,target_size=(img_height,img_width),class_mode='binary',batch_size=batch_size)
test = test_data_gen.flow_from_directory(test_path,target_size=(img_height,img_width),shuffle=False,class_mode='binary',batch_size=batch_size)
valid = test_data_gen.flow_from_directory(valid_path,target_size=(img_height,img_width),class_mode='binary',batch_size=batch_size)
# Out:
# Found 4883 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 349 images belonging to 2 classes.

# %%
plt.figure(figsize=(12,12))
for i in range(0,10):
  plt.subplot(2,5,i+1)
  for X_batch,Y_batch in train:
    image = X_batch[0]
    dic = {0:'Normal',1:'Pneumonia'}
    plt.title(dic.get(Y_batch[0]))
    plt.axis('off')

    plt.imshow(np.squeeze(image),cmap='gray',interpolation='nearest')
    break

    plt.tight_layout()
    plt.show()

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, BatchNormalization, SeparableConv2D

from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# %%
model = Sequential()

model.add(SeparableConv2D(32,(3,3),input_shape=(img_width,img_height,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(SeparableConv2D(32,(3,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(SeparableConv2D(64,(3,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(SeparableConv2D(64,(3,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(SeparableConv2D(128,(3,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(SeparableConv2D(128,(3,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(SeparableConv2D(256,(3,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(SeparableConv2D(256,(3,3),kernel_initializer='he_normal',activation='swish'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(128,activation='relu'))

# model.add(keras.layers.ELU())

model.add(BatchNormalization())

model.add(Dense(64,activation='relu'))

model.add(BatchNormalization())

model.add(Dropout(0.5))

model.add(Dense(activation='sigmoid',units=1))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d (SeparableC (None, 148, 148, 32)      155
# _________________________________________________________________
# batch_normalization (BatchNo (None, 148, 148, 32)      128
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 146, 146, 32)      1344
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 146, 146, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 32)        0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 71, 71, 64)        2400
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 71, 71, 64)        256
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 69, 69, 64)        4736
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 69, 69, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 64)        0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 32, 32, 128)       8896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# separable_conv2d_5 (Separabl (None, 30, 30, 128)       17664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 30, 30, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 13, 13, 256)       34176
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 13, 13, 256)       1024
# _________________________________________________________________
# separable_conv2d_7 (Separabl (None, 11, 11, 256)       68096
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 969,724
# Trainable params: 967,420
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True,show_layer_names=True,rankdir='TB',expand_nested=True)

# %%
early = EarlyStopping(monitor="val_loss",mode="min",patience=3)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',patience=2,verbose=1,factor=0.3,min_lr=0.000001)
callbacks_list = [early,learning_rate_reduction]

# %%
from sklearn.utils.class_weight import compute_class_weight
weights = compute_class_weight('balanced',np.unique(train.classes),train.classes)
cw = dict(zip(np.unique(train.classes),weights))
print(cw)
# Out:
# {0: 2.0761054421768708, 1: 0.6586188292419747}

# %%
model.fit(train,epochs=25,validation_data=valid,class_weight=cw,batch_size=512)
# Out:
# Epoch 1/25
# 257/257 [==============================] - 110s 305ms/step - loss: 0.5462 - accuracy: 0.7593 - val_loss: 0.8202 - val_accuracy: 0.5043
# Epoch 2/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.3520 - accuracy: 0.8555 - val_loss: 1.6630 - val_accuracy: 0.5043
# Epoch 3/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.3295 - accuracy: 0.8680 - val_loss: 0.4168 - val_accuracy: 0.8109
# Epoch 4/25
# 257/257 [==============================] - 77s 301ms/step - loss: 0.3025 - accuracy: 0.8768 - val_loss: 0.5940 - val_accuracy: 0.7994
# Epoch 5/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.2563 - accuracy: 0.8885 - val_loss: 0.4692 - val_accuracy: 0.8080
# Epoch 6/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.2944 - accuracy: 0.8783 - val_loss: 0.2501 - val_accuracy: 0.9140
# Epoch 7/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.2462 - accuracy: 0.9009 - val_loss: 0.2656 - val_accuracy: 0.8854
# Epoch 8/25
# 257/257 [==============================] - 78s 301ms/step - loss: 0.2553 - accuracy: 0.8976 - val_loss: 0.3218 - val_accuracy: 0.8481
# Epoch 9/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.2439 - accuracy: 0.8923 - val_loss: 0.1521 - val_accuracy: 0.9513
# Epoch 10/25
# 257/257 [==============================] - 79s 306ms/step - loss: 0.2113 - accuracy: 0.9189 - val_loss: 0.3314 - val_accuracy: 0.8711
# Epoch 11/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.2036 - accuracy: 0.9224 - val_loss: 0.2633 - val_accuracy: 0.9054
# Epoch 12/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.2237 - accuracy: 0.9100 - val_loss: 0.1572 - val_accuracy: 0.9370
# Epoch 13/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.1935 - accuracy: 0.9207 - val_loss: 0.4007 - val_accuracy: 0.8825
# Epoch 14/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.1880 - accuracy: 0.9261 - val_loss: 0.6353 - val_accuracy: 0.7536
# Epoch 15/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.1745 - accuracy: 0.9323 - val_loss: 0.2594 - val_accuracy: 0.9054
# Epoch 16/25
# 257/257 [==============================] - 78s 304ms/step - loss: 0.1701 - accuracy: 0.9345 - val_loss: 0.4256 - val_accuracy: 0.8309
# Epoch 17/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.1737 - accuracy: 0.9295 - val_loss: 0.6801 - val_accuracy: 0.7192
# Epoch 18/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.1648 - accuracy: 0.9318 - val_loss: 0.1849 - val_accuracy: 0.9284
# Epoch 19/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.1624 - accuracy: 0.9287 - val_loss: 0.4929 - val_accuracy: 0.8252
# Epoch 20/25
# 257/257 [==============================] - 78s 303ms/step - loss: 0.1803 - accuracy: 0.9239 - val_loss: 0.4549 - val_accuracy: 0.8252
# Epoch 21/25
# 257/257 [==============================] - 78s 305ms/step - loss: 0.1717 - accuracy: 0.9315 - val_loss: 0.1986 - val_accuracy: 0.9198
# Epoch 22/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.1636 - accuracy: 0.9374 - val_loss: 0.7177 - val_accuracy: 0.7106
# Epoch 23/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.1546 - accuracy: 0.9380 - val_loss: 0.2181 - val_accuracy: 0.9112
# Epoch 24/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.1476 - accuracy: 0.9400 - val_loss: 0.6805 - val_accuracy: 0.6934
# Epoch 25/25
# 257/257 [==============================] - 77s 301ms/step - loss: 0.1353 - accuracy: 0.9473 - val_loss: 0.1799 - val_accuracy: 0.9341

# %%
pd.DataFrame(model.history.history).plot()

# %%
test_accu = model.evaluate(test)
print('The testing accuracy is - ',test_accu[1]*100,'%')
# Out:
# 33/33 [==============================] - 6s 174ms/step - loss: 0.2084 - accuracy: 0.9183
# The testing accuracy is -  91.82692170143127 %

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,f1_score, log_loss

y_bar = np.round(model.predict(test)).reshape(-1)
y_act = test.labels

##accuracy
print("Accuracy: ",accuracy_score(y_bar,y_act))
##Roc_Auc Score
print("ROC-AUC score: ",roc_auc_score(y_bar,y_act))
##F1-Score Score
print("F1 score: ",f1_score(y_bar,y_act))
##Log Loss Score
print("Log Loss: ",log_loss(y_bar,y_act))
# Out:
# Accuracy:  0.9182692307692307
# ROC-AUC score:  0.9131038494890399
# F1 score:  0.9346991037131882
# Log Loss:  2.8229127981990385
