# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-390f62ce-0c9d-4ac0-919c-a9a4ec464807" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-390f62ce-0c9d-4ac0-919c-a9a4ec464807">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets download -d mrinath/pneumonia
# Out:
# Downloading pneumonia.zip to /content
# 100% 1.17G/1.17G [00:13<00:00, 102MB/s]
# 100% 1.17G/1.17G [00:13<00:00, 92.0MB/s]

# %%
import zipfile
zf = "/content/pneumonia.zip"
target_dir = "/content/dataset/cnn/pneumonia"
zfile = zipfile.ZipFile(zf)
zfile.extractall(target_dir)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
train_path = '/content/dataset/cnn/pneumonia/folders/train'
test_path = '/content/dataset/cnn/pneumonia/folders/test'
valid_path = '/content/dataset/cnn/pneumonia/folders/valid'

# %%
batch_size = 19

img_height = 150
img_width = 150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
image_gen = ImageDataGenerator(rescale=1./255,zoom_range=0.4,shear_range=0.3,vertical_flip=True)
test_data_gen = ImageDataGenerator(rescale=1./255)

# %%
train = image_gen.flow_from_directory(train_path,target_size=(img_height,img_width),class_mode='binary',batch_size=batch_size)
test = test_data_gen.flow_from_directory(test_path,target_size=(img_height,img_width),shuffle=False,class_mode='binary',batch_size=batch_size)
valid = test_data_gen.flow_from_directory(valid_path,target_size=(img_height,img_width),class_mode='binary',batch_size=batch_size)
# Out:
# Found 4883 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 349 images belonging to 2 classes.

# %%
plt.figure(figsize=(12,12))
for i in range(0,10):
  plt.subplot(2,5,i+1)
  for X_batch,Y_batch in train:
    image = X_batch[0]
    dic = {0:'Normal',1:'Pneumonia'}
    plt.title(dic.get(Y_batch[0]))
    plt.axis('off')

    plt.imshow(np.squeeze(image),cmap='gray',interpolation='nearest')
    break

    plt.tight_layout()
    plt.show()

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, BatchNormalization, SeparableConv2D

from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# %%
model = Sequential()

model.add(SeparableConv2D(32,(3,3),input_shape=(img_width,img_height,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(SeparableConv2D(32,(3,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(SeparableConv2D(64,(3,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(SeparableConv2D(64,(3,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(SeparableConv2D(128,(3,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(SeparableConv2D(128,(3,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(SeparableConv2D(256,(3,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(SeparableConv2D(256,(3,3),kernel_initializer='glorot_uniform'))
model.add(BatchNormalization())
model.add(keras.layers.ELU())

model.add(MaxPooling2D(pool_size=(2,2)))

# model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(128,activation='relu'))

# model.add(keras.layers.ELU())

model.add(BatchNormalization())

model.add(Dense(64,activation='relu'))

model.add(BatchNormalization())

model.add(Dropout(0.5))

model.add(Dense(activation='sigmoid',units=1))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d (SeparableC (None, 148, 148, 32)      155
# _________________________________________________________________
# batch_normalization (BatchNo (None, 148, 148, 32)      128
# _________________________________________________________________
# elu (ELU)                    (None, 148, 148, 32)      0
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 146, 146, 32)      1344
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 146, 146, 32)      128
# _________________________________________________________________
# elu_1 (ELU)                  (None, 146, 146, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 32)        0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 71, 71, 64)        2400
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 71, 71, 64)        256
# _________________________________________________________________
# elu_2 (ELU)                  (None, 71, 71, 64)        0
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 69, 69, 64)        4736
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 69, 69, 64)        256
# _________________________________________________________________
# elu_3 (ELU)                  (None, 69, 69, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 64)        0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 32, 32, 128)       8896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# elu_4 (ELU)                  (None, 32, 32, 128)       0
# _________________________________________________________________
# separable_conv2d_5 (Separabl (None, 30, 30, 128)       17664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 30, 30, 128)       512
# _________________________________________________________________
# elu_5 (ELU)                  (None, 30, 30, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 13, 13, 256)       34176
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 13, 13, 256)       1024
# _________________________________________________________________
# elu_6 (ELU)                  (None, 13, 13, 256)       0
# _________________________________________________________________
# separable_conv2d_7 (Separabl (None, 11, 11, 256)       68096
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# elu_7 (ELU)                  (None, 11, 11, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 969,724
# Trainable params: 967,420
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True,show_layer_names=True,rankdir='TB',expand_nested=True)

# %%
early = EarlyStopping(monitor="val_loss",mode="min",patience=3)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',patience=2,verbose=1,factor=0.3,min_lr=0.000001)
callbacks_list = [early,learning_rate_reduction]

# %%
from sklearn.utils.class_weight import compute_class_weight
weights = compute_class_weight('balanced',np.unique(train.classes),train.classes)
cw = dict(zip(np.unique(train.classes),weights))
print(cw)
# Out:
# {0: 2.0761054421768708, 1: 0.6586188292419747}

# %%
model.fit(train,epochs=25,validation_data=valid,class_weight=cw,batch_size=512)
# Out:
# Epoch 1/25
# 257/257 [==============================] - 111s 300ms/step - loss: 0.5109 - accuracy: 0.7602 - val_loss: 0.9144 - val_accuracy: 0.5043
# Epoch 2/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.3477 - accuracy: 0.8506 - val_loss: 0.5732 - val_accuracy: 0.7507
# Epoch 3/25
# 257/257 [==============================] - 77s 299ms/step - loss: 0.3523 - accuracy: 0.8523 - val_loss: 0.2988 - val_accuracy: 0.8940
# Epoch 4/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.2700 - accuracy: 0.8762 - val_loss: 0.8472 - val_accuracy: 0.6848
# Epoch 5/25
# 257/257 [==============================] - 77s 298ms/step - loss: 0.2578 - accuracy: 0.8917 - val_loss: 0.1746 - val_accuracy: 0.9398
# Epoch 6/25
# 257/257 [==============================] - 77s 299ms/step - loss: 0.2690 - accuracy: 0.9021 - val_loss: 0.3370 - val_accuracy: 0.8997
# Epoch 7/25
# 257/257 [==============================] - 77s 299ms/step - loss: 0.2417 - accuracy: 0.9037 - val_loss: 0.4107 - val_accuracy: 0.8883
# Epoch 8/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.2437 - accuracy: 0.9008 - val_loss: 0.2275 - val_accuracy: 0.9169
# Epoch 9/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.2217 - accuracy: 0.9111 - val_loss: 0.2157 - val_accuracy: 0.9284
# Epoch 10/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.2153 - accuracy: 0.9177 - val_loss: 0.5971 - val_accuracy: 0.8395
# Epoch 11/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.2065 - accuracy: 0.9229 - val_loss: 0.9243 - val_accuracy: 0.6017
# Epoch 12/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.2071 - accuracy: 0.9241 - val_loss: 0.3550 - val_accuracy: 0.8653
# Epoch 13/25
# 257/257 [==============================] - 77s 299ms/step - loss: 0.2044 - accuracy: 0.9204 - val_loss: 0.4369 - val_accuracy: 0.8424
# Epoch 14/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.2097 - accuracy: 0.9257 - val_loss: 0.2001 - val_accuracy: 0.9341
# Epoch 15/25
# 257/257 [==============================] - 77s 301ms/step - loss: 0.2055 - accuracy: 0.9203 - val_loss: 0.1342 - val_accuracy: 0.9513
# Epoch 16/25
# 257/257 [==============================] - 78s 301ms/step - loss: 0.1839 - accuracy: 0.9281 - val_loss: 0.3062 - val_accuracy: 0.8940
# Epoch 17/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.1816 - accuracy: 0.9307 - val_loss: 0.2627 - val_accuracy: 0.8825
# Epoch 18/25
# 257/257 [==============================] - 78s 301ms/step - loss: 0.1935 - accuracy: 0.9246 - val_loss: 0.2970 - val_accuracy: 0.8768
# Epoch 19/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.1691 - accuracy: 0.9301 - val_loss: 0.2938 - val_accuracy: 0.9026
# Epoch 20/25
# 257/257 [==============================] - 78s 302ms/step - loss: 0.1934 - accuracy: 0.9216 - val_loss: 0.2691 - val_accuracy: 0.8940
# Epoch 21/25
# 257/257 [==============================] - 77s 301ms/step - loss: 0.1928 - accuracy: 0.9225 - val_loss: 0.1912 - val_accuracy: 0.9255
# Epoch 22/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.1884 - accuracy: 0.9304 - val_loss: 0.4132 - val_accuracy: 0.8481
# Epoch 23/25
# 257/257 [==============================] - 77s 301ms/step - loss: 0.1867 - accuracy: 0.9300 - val_loss: 0.3057 - val_accuracy: 0.8940
# Epoch 24/25
# 257/257 [==============================] - 78s 301ms/step - loss: 0.1950 - accuracy: 0.9248 - val_loss: 0.1365 - val_accuracy: 0.9599
# Epoch 25/25
# 257/257 [==============================] - 77s 300ms/step - loss: 0.1627 - accuracy: 0.9415 - val_loss: 0.2001 - val_accuracy: 0.9255

# %%
pd.DataFrame(model.history.history).plot()

# %%
test_accu = model.evaluate(test)
print('The testing accuracy is - ',test_accu[1]*100,'%')
# Out:
# 33/33 [==============================] - 6s 178ms/step - loss: 0.1426 - accuracy: 0.9407
# The testing accuracy is -  94.07051205635071 %

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,f1_score, log_loss

y_bar = np.round(model.predict(test)).reshape(-1)
y_act = test.labels

##accuracy
print("Accuracy: ",accuracy_score(y_bar,y_act))
##Roc_Auc Score
print("ROC-AUC score: ",roc_auc_score(y_bar,y_act))
##F1-Score Score
print("F1 score: ",f1_score(y_bar,y_act))
##Log Loss Score
print("Log Loss: ",log_loss(y_bar,y_act))
# Out:
# Accuracy:  0.9407051282051282
# ROC-AUC score:  0.9338700123849013
# F1 score:  0.951885565669701
# Log Loss:  2.048003072035289
