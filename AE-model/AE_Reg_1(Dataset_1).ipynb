# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-8624a876-92b2-4964-9934-367c73b1ca39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8624a876-92b2-4964-9934-367c73b1ca39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !kaggle datasets download -d pcbreviglieri/pneumonia-xray-images
# Out:
# Downloading pneumonia-xray-images.zip to /content
#  99% 1.13G/1.14G [00:15<00:00, 68.5MB/s]
# 100% 1.14G/1.14G [00:15<00:00, 77.4MB/s]

# %%
import zipfile
zf = "/content/pneumonia-xray-images.zip"
target_dir = "/content/dataset/cnn/pneumonia_revamped"
zfile = zipfile.ZipFile(zf)
zfile.extractall(target_dir)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
train_path = '/content/dataset/cnn/pneumonia_revamped/train'
test_path = '/content/dataset/cnn/pneumonia_revamped/test'
valid_path = '/content/dataset/cnn/pneumonia_revamped/val'

# %%
batch_size = 32

img_height = 150
img_width = 150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
image_gen = ImageDataGenerator(rescale=1./255,zoom_range=0.4,shear_range=0.3,vertical_flip=True)
test_data_gen = ImageDataGenerator(rescale=1./255)

# %%
train = image_gen.flow_from_directory(train_path,target_size=(img_height,img_width),class_mode='binary',color_mode='grayscale',batch_size=batch_size)
test = test_data_gen.flow_from_directory(test_path,target_size=(img_height,img_width),shuffle=False,class_mode='binary',color_mode='grayscale',batch_size=batch_size)
valid = test_data_gen.flow_from_directory(valid_path,target_size=(img_height,img_width),class_mode='binary',color_mode='grayscale',batch_size=batch_size)

decoder_input = test_data_gen.flow_from_directory(train_path,target_size=(img_height,img_width),class_mode='binary',color_mode='grayscale',batch_size=batch_size,shuffle=False)
decoder_output = test_data_gen.flow_from_directory(train_path,target_size=(40,40),class_mode='binary',color_mode='grayscale',batch_size=batch_size,shuffle=False)
# Out:
# Found 4192 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 1040 images belonging to 2 classes.
# Found 4192 images belonging to 2 classes.
# Found 4192 images belonging to 2 classes.

# %%
import tensorflow as tf

import os
import keras
from keras.models import Sequential, Model
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, BatchNormalization, Input, SeparableConv2D, UpSampling2D

from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
from tqdm.notebook import tqdm

from keras.optimizers import SGD

# %%
#Creating the decoder's data
X = []
Y = []
for _ in tqdm(range(131)):
    X += list(decoder_input.next()[0])
    Y += list(decoder_output.next()[0])
X = np.array(X)
Y = np.array(Y)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=131.0), HTML(value='')))

# %%
plt.figure(figsize=(12,12))
for i in range(0,10):
  plt.subplot(2,5,i+1)
  for X_batch,Y_batch in train:
    image = X_batch[0]
    dic = {0:'Normal',1:'Pneumonia'}
    plt.title(dic.get(Y_batch[0]))
    plt.axis('off')

    plt.imshow(np.squeeze(image),cmap='gray',interpolation='nearest')
    break

    plt.tight_layout()
    plt.show()

# %%
def SeparableConvBlock(filter_n,kernel_shape,pool_size,init,input_shape,name=None):
    
    input_layer = Input(input_shape)
    
    model = SeparableConv2D(filter_n,kernel_shape,input_shape=(img_width,img_height,1),kernel_initializer=init)(input_layer)
    model = BatchNormalization()(model)
    model = keras.layers.ELU()(model)

    model = SeparableConv2D(filter_n,kernel_shape,kernel_initializer=init)(model)
    model = BatchNormalization()(model)
    model = keras.layers.ELU()(model)


    model = MaxPooling2D(pool_size=pool_size)(model)
    
    return Model(input_layer,model,name=name),model.shape

# %%
input_layer = Input(shape=(img_height,img_width,1))

#Encoder

layer,shape = SeparableConvBlock(32,(3,3),(2,2),'glorot_uniform',(img_width,img_height,1),"SPB1")
enc = layer(input_layer)
layer,shape = SeparableConvBlock(64,(3,3),(2,2),'glorot_uniform',(shape[1:]),"SPB2")
enc = layer(enc)
layer,shape = SeparableConvBlock(128,(3,3),(2,2),'glorot_uniform',(shape[1:]),"SPB3")
enc = layer(enc)
layer,shape = SeparableConvBlock(256,(3,3),(2,2),'glorot_uniform',(shape[1:]),"SPB4")
enc = layer(enc)

Encoder = Model(input_layer,enc)

#Decoder

decoder = SeparableConv2D(128, (3, 3), activation='sigmoid', padding='same')(enc)
decoder = BatchNormalization()(decoder)
decoder = SeparableConv2D(128, (3, 3), activation='sigmoid', padding='same')(decoder)
decoder = BatchNormalization()(decoder)
decoder = UpSampling2D((2,2))(decoder)

decoder = SeparableConv2D(64, (3, 3), activation='sigmoid', padding='same')(decoder)
decoder = BatchNormalization()(decoder)
decoder = SeparableConv2D(64, (3, 3), activation='sigmoid', padding='same')(decoder)
decoder = BatchNormalization()(decoder)
decoder = UpSampling2D((2,2))(decoder)

decoder = SeparableConv2D(32, (3, 3), activation='sigmoid', padding='same')(decoder)
decoder = BatchNormalization()(decoder)
decoder = SeparableConv2D(32, (3, 3), activation='sigmoid', padding='same')(decoder)
decoder = BatchNormalization()(decoder)
decoder = UpSampling2D((2,2))(decoder)


decoder = SeparableConv2D(1, (3, 3), activation='sigmoid', padding='same')(decoder)

Decoder = Model(input_layer,decoder)
                
                
#Classifier
flatten = Flatten()(enc)
dense = Dense(128,activation='relu')(flatten)
dense = BatchNormalization()(dense)
dense = Dense(64,activation='relu')(dense)
dense = BatchNormalization()(dense)
dense = Dropout(0.5)(dense)
dense = Dense(1,activation='sigmoid')(dense)

Classifier = Model(input_layer,dense)

# %%
Decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# SPB1 (Functional)            (None, 73, 73, 32)        1673
# _________________________________________________________________
# SPB2 (Functional)            (None, 34, 34, 64)        7648
# _________________________________________________________________
# SPB3 (Functional)            (None, 15, 15, 128)       27584
# _________________________________________________________________
# SPB4 (Functional)            (None, 5, 5, 256)         104320
# _________________________________________________________________
# separable_conv2d_8 (Separabl (None, 5, 5, 128)         35200
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# separable_conv2d_9 (Separabl (None, 5, 5, 128)         17664
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 128)         512
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 10, 10, 128)       0
# _________________________________________________________________
# separable_conv2d_10 (Separab (None, 10, 10, 64)        9408
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# separable_conv2d_11 (Separab (None, 10, 10, 64)        4736
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 10, 10, 64)        256
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 20, 20, 64)        0
# _________________________________________________________________
# separable_conv2d_12 (Separab (None, 20, 20, 32)        2656
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 20, 20, 32)        128
# _________________________________________________________________
# separable_conv2d_13 (Separab (None, 20, 20, 32)        1344
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 20, 20, 32)        128
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 40, 40, 32)        0
# _________________________________________________________________
# separable_conv2d_14 (Separab (None, 40, 40, 1)         321
# =================================================================
# Total params: 214,346
# Trainable params: 211,530
# Non-trainable params: 2,816
# _________________________________________________________________

# %%
Decoder.compile(loss='mean_squared_error', optimizer = SGD())

# %%
Decoder.fit(X,Y,batch_size=batch_size,epochs=30)
# Out:
# Epoch 1/30
# 131/131 [==============================] - 68s 277ms/step - loss: 0.0468
# Epoch 2/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0307
# Epoch 3/30
# 131/131 [==============================] - 36s 277ms/step - loss: 0.0266
# Epoch 4/30
# 131/131 [==============================] - 36s 274ms/step - loss: 0.0241
# Epoch 5/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0225
# Epoch 6/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0212
# Epoch 7/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0201
# Epoch 8/30
# 131/131 [==============================] - 36s 277ms/step - loss: 0.0196
# Epoch 9/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0189
# Epoch 10/30
# 131/131 [==============================] - 36s 277ms/step - loss: 0.0183
# Epoch 11/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0179
# Epoch 12/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0174
# Epoch 13/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0173
# Epoch 14/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0168
# Epoch 15/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0165
# Epoch 16/30
# 131/131 [==============================] - 36s 274ms/step - loss: 0.0162
# Epoch 17/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0161
# Epoch 18/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0159
# Epoch 19/30
# 131/131 [==============================] - 36s 277ms/step - loss: 0.0157
# Epoch 20/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0154
# Epoch 21/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0153
# Epoch 22/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0151
# Epoch 23/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0151
# Epoch 24/30
# 131/131 [==============================] - 36s 278ms/step - loss: 0.0150
# Epoch 25/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0150
# Epoch 26/30
# 131/131 [==============================] - 36s 274ms/step - loss: 0.0146
# Epoch 27/30
# 131/131 [==============================] - 36s 273ms/step - loss: 0.0146
# Epoch 28/30
# 131/131 [==============================] - 36s 273ms/step - loss: 0.0146
# Epoch 29/30
# 131/131 [==============================] - 36s 276ms/step - loss: 0.0143
# Epoch 30/30
# 131/131 [==============================] - 36s 275ms/step - loss: 0.0141

# %%
predictions = Decoder.predict(X)

# %%
plt.imshow((tf.squeeze(predictions[0])))
plt.show()

# %%
plt.imshow((tf.squeeze(X[0])))
plt.show()

# %%
plt.imshow((tf.squeeze(Y[0])))
plt.show()

# %%
Classifier.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 1)]     0
# _________________________________________________________________
# SPB1 (Functional)            (None, 73, 73, 32)        1673
# _________________________________________________________________
# SPB2 (Functional)            (None, 34, 34, 64)        7648
# _________________________________________________________________
# SPB3 (Functional)            (None, 15, 15, 128)       27584
# _________________________________________________________________
# SPB4 (Functional)            (None, 5, 5, 256)         104320
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 969,642
# Trainable params: 967,338
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
Classifier.compile(optimizer=SGD(),loss='binary_crossentropy',metrics=['accuracy'])

# %%
from sklearn.utils.class_weight import compute_class_weight
weights = compute_class_weight('balanced',np.unique(train.classes),train.classes)
cw = dict(zip(np.unique(train.classes),weights))
print(cw)
# Out:
# {0: 1.9371534195933457, 1: 0.6739549839228296}

# %%
Classifier.fit(train,epochs=25,validation_data=valid,class_weight=cw,batch_size=512)
# Out:
# Epoch 1/25
# 131/131 [==============================] - 70s 523ms/step - loss: 0.5988 - accuracy: 0.6947 - val_loss: 0.6236 - val_accuracy: 0.7317
# Epoch 2/25
# 131/131 [==============================] - 67s 513ms/step - loss: 0.3727 - accuracy: 0.8226 - val_loss: 0.3211 - val_accuracy: 0.8692
# Epoch 3/25
# 131/131 [==============================] - 68s 519ms/step - loss: 0.3390 - accuracy: 0.8513 - val_loss: 0.2445 - val_accuracy: 0.9125
# Epoch 4/25
# 131/131 [==============================] - 68s 519ms/step - loss: 0.3065 - accuracy: 0.8757 - val_loss: 0.3478 - val_accuracy: 0.8529
# Epoch 5/25
# 131/131 [==============================] - 69s 523ms/step - loss: 0.2749 - accuracy: 0.8905 - val_loss: 0.4040 - val_accuracy: 0.8365
# Epoch 6/25
# 131/131 [==============================] - 68s 517ms/step - loss: 0.2894 - accuracy: 0.8809 - val_loss: 0.2470 - val_accuracy: 0.9019
# Epoch 7/25
# 131/131 [==============================] - 69s 523ms/step - loss: 0.2390 - accuracy: 0.9035 - val_loss: 0.3599 - val_accuracy: 0.8769
# Epoch 8/25
# 131/131 [==============================] - 69s 525ms/step - loss: 0.2266 - accuracy: 0.9114 - val_loss: 0.4328 - val_accuracy: 0.8212
# Epoch 9/25
# 131/131 [==============================] - 69s 528ms/step - loss: 0.2291 - accuracy: 0.9079 - val_loss: 0.3716 - val_accuracy: 0.8375
# Epoch 10/25
# 131/131 [==============================] - 70s 530ms/step - loss: 0.1965 - accuracy: 0.9250 - val_loss: 0.2243 - val_accuracy: 0.9240
# Epoch 11/25
# 131/131 [==============================] - 70s 532ms/step - loss: 0.2173 - accuracy: 0.9137 - val_loss: 0.3434 - val_accuracy: 0.8673
# Epoch 12/25
# 131/131 [==============================] - 69s 526ms/step - loss: 0.2366 - accuracy: 0.9106 - val_loss: 0.2945 - val_accuracy: 0.8875
# Epoch 13/25
# 131/131 [==============================] - 70s 530ms/step - loss: 0.2157 - accuracy: 0.9171 - val_loss: 0.2482 - val_accuracy: 0.9077
# Epoch 14/25
# 131/131 [==============================] - 69s 522ms/step - loss: 0.1954 - accuracy: 0.9198 - val_loss: 0.2371 - val_accuracy: 0.8990
# Epoch 15/25
# 131/131 [==============================] - 69s 523ms/step - loss: 0.1974 - accuracy: 0.9295 - val_loss: 0.2294 - val_accuracy: 0.9183
# Epoch 16/25
# 131/131 [==============================] - 69s 523ms/step - loss: 0.1875 - accuracy: 0.9302 - val_loss: 0.2197 - val_accuracy: 0.9144
# Epoch 17/25
# 131/131 [==============================] - 69s 524ms/step - loss: 0.1839 - accuracy: 0.9301 - val_loss: 0.1781 - val_accuracy: 0.9462
# Epoch 18/25
# 131/131 [==============================] - 69s 523ms/step - loss: 0.1763 - accuracy: 0.9360 - val_loss: 0.3463 - val_accuracy: 0.8625
# Epoch 19/25
# 131/131 [==============================] - 68s 521ms/step - loss: 0.1735 - accuracy: 0.9294 - val_loss: 0.5839 - val_accuracy: 0.7827
# Epoch 20/25
# 131/131 [==============================] - 68s 521ms/step - loss: 0.1778 - accuracy: 0.9333 - val_loss: 0.2965 - val_accuracy: 0.8856
# Epoch 21/25
# 131/131 [==============================] - 69s 525ms/step - loss: 0.1761 - accuracy: 0.9372 - val_loss: 0.1884 - val_accuracy: 0.9212
# Epoch 22/25
# 131/131 [==============================] - 69s 522ms/step - loss: 0.1637 - accuracy: 0.9346 - val_loss: 0.1874 - val_accuracy: 0.9279
# Epoch 23/25
# 131/131 [==============================] - 69s 524ms/step - loss: 0.1705 - accuracy: 0.9379 - val_loss: 0.2652 - val_accuracy: 0.9125
# Epoch 24/25
# 131/131 [==============================] - 68s 520ms/step - loss: 0.1633 - accuracy: 0.9415 - val_loss: 0.2638 - val_accuracy: 0.9115
# Epoch 25/25
# 131/131 [==============================] - 68s 520ms/step - loss: 0.1576 - accuracy: 0.9384 - val_loss: 0.2140 - val_accuracy: 0.9202

# %%
pd.DataFrame(Classifier.history.history).plot()

# %%
test_accu = Classifier.evaluate(test)
print('The testing accuracy is - ',test_accu[1]*100,'%')
# Out:
# 20/20 [==============================] - 5s 241ms/step - loss: 0.2540 - accuracy: 0.8990
# The testing accuracy is -  89.90384340286255 %

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,f1_score, log_loss

# %%
y_bar = np.round(Classifier.predict(test)).reshape(-1)
y_act = test.labels

# %%
##accuracy
print("Accuracy: ",accuracy_score(y_bar,y_act))
##Roc_Auc Score
print("ROC-AUC score: ",roc_auc_score(y_bar,y_act))
##F1-Score Score
print("F1 score: ",f1_score(y_bar,y_act))
##Log Loss Score
print("Log Loss: ",log_loss(y_bar,y_act))
# Out:
# Accuracy:  0.8990384615384616
# ROC-AUC score:  0.9025649045980608
# F1 score:  0.9219330855018588
# Log Loss:  3.4871110667197387

# %%
Classifier.save('custom_cnn.h5')
